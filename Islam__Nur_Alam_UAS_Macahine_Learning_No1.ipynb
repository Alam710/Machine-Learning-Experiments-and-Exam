# %% [markdown]
# <a href="https://colab.research.google.com/github/Alam710/Python_Basic_and_exam_machine_learning_MTI/blob/master/Islam__Nur_Alam_UAS_Macahine_Learning_No1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# # Impoert Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Exploratory Data Analysis

# %%
df = pd.read_excel("/content/drive/MyDrive/UAS_ML/Placement_Data_Full_Class.xlsx", index_col='No')
df.head()
# Out:
#    gender  ...    salary
# No         ...
# 1       M  ...  270000.0
# 2       M  ...  200000.0
# 3       M  ...  250000.0
# 4       M  ...       NaN
# 5       M  ...  425000.0
#
# [5 rows x 14 columns]

# %% [markdown]
# # Split Numerical Data

# %%
df.columns
# Out:
# Index(['gender', 'Secondary Education Percentage - 10th Grade',
#        'Board of Secondary Education ',
#        'Higher Secondary Education Percentage - 12th Grade',
#        'Board of Higher Secondary Education',
#        'Specialization in  Higher Secondary Education', 'Degree Percentage',
#        'Field of Degree Education', 'Work Experience',
#        'Employability test percentage ( conducted by college)',
#        'Post Graduation Specialisation', 'Post Graduation Percentage',
#        'Status of Placement', 'salary'],
#       dtype='object')

# %%
num_colums = ['Secondary Education Percentage - 10th Grade',
              'Higher Secondary Education Percentage - 12th Grade',
              'Degree Percentage',
              'Employability test percentage ( conducted by college)',
              'Post Graduation Percentage',
              'salary']
df_numerical = df[num_colums]
df_numerical
# Out:
#      Secondary Education Percentage - 10th Grade  ...    salary
# No                                                ...
# 1                                          67.00  ...  270000.0
# 2                                          79.33  ...  200000.0
# 3                                          65.00  ...  250000.0
# 4                                          56.00  ...       NaN
# 5                                          85.80  ...  425000.0
# ..                                           ...  ...       ...
# 211                                        80.60  ...  400000.0
# 212                                        58.00  ...  275000.0
# 213                                        67.00  ...  295000.0
# 214                                        74.00  ...  204000.0
# 215                                        62.00  ...       NaN
#
# [215 rows x 6 columns]

# %% [markdown]
# # Split Categorical Data

# %%
categorical_columns = df.columns.drop(num_colums)
categorical_columns
# Out:
# Index(['gender', 'Board of Secondary Education ',
#        'Board of Higher Secondary Education',
#        'Specialization in  Higher Secondary Education',
#        'Field of Degree Education', 'Work Experience',
#        'Post Graduation Specialisation', 'Status of Placement'],
#       dtype='object')

# %%
df_categorical = df[categorical_columns]
df_categorical
# Out:
#     gender  ... Status of Placement
# No          ...
# 1        M  ...              Placed
# 2        M  ...              Placed
# 3        M  ...              Placed
# 4        M  ...          Not Placed
# 5        M  ...              Placed
# ..     ...  ...                 ...
# 211      M  ...              Placed
# 212      M  ...              Placed
# 213      M  ...              Placed
# 214      F  ...              Placed
# 215      M  ...          Not Placed
#
# [215 rows x 8 columns]

# %% [markdown]
# # visualization

# %% [markdown]
# # Box Plots

# %%
df_box = df_numerical.drop('salary', axis = 1)
df_box.columns
# Out:
# Index(['Secondary Education Percentage - 10th Grade',
#        'Higher Secondary Education Percentage - 12th Grade',
#        'Degree Percentage',
#        'Employability test percentage ( conducted by college)',
#        'Post Graduation Percentage'],
#       dtype='object')

# %%
sns.set_theme(style='whitegrid')
ax = sns.boxplot(data=df_box, orient='h')

# %% [markdown]
# # Bar Chart

# %%
df_categorical.columns
# Out:
# Index(['gender', 'Board of Secondary Education ',
#        'Board of Higher Secondary Education',
#        'Specialization in  Higher Secondary Education',
#        'Field of Degree Education', 'Work Experience',
#        'Post Graduation Specialisation', 'Status of Placement'],
#       dtype='object')

# %% [markdown]
# # Gender

# %%
sns.set_theme(style='darkgrid')
ax = sns.countplot(y='gender', data=df_categorical)
df_categorical['gender'].value_counts()
# Out:
# M    139
# F     76
# Name: gender, dtype: int64

# %% [markdown]
# # Board of Secondary Education

# %%
sns.set_theme(style='darkgrid')
ax = sns.countplot(y='Board of Secondary Education ', data=df_categorical)
df_categorical['Board of Secondary Education '].value_counts()
# Out:
# Central    116
# Others      99
# Name: Board of Secondary Education , dtype: int64

# %% [markdown]
# # Specialization in Higher Secondary Education

# %%
sns.set_theme(style='darkgrid')
ax = sns.countplot(y='Specialization in  Higher Secondary Education', data=df_categorical)
df_categorical['Specialization in  Higher Secondary Education'].value_counts()
# Out:
# Commerce    113
# Science      91
# Arts         11
# Name: Specialization in  Higher Secondary Education, dtype: int64

# %% [markdown]
# # Field of Degree Education

# %%
sns.set_theme(style='darkgrid')
ax = sns.countplot(y='Field of Degree Education', data=df_categorical)
df_categorical['Field of Degree Education'].value_counts()
# Out:
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: Field of Degree Education, dtype: int64

# %% [markdown]
# # Work Experience

# %%
sns.set_theme(style='darkgrid')
ax = sns.countplot(y='Work Experience', data=df_categorical)
df_categorical['Work Experience'].value_counts()
# Out:
# No     141
# Yes     74
# Name: Work Experience, dtype: int64

# %% [markdown]
# # Post Graduation Specialisation

# %%
sns.set_theme(style='darkgrid')
ax = sns.countplot(y='Post Graduation Specialisation', data=df_categorical)
df_categorical['Post Graduation Specialisation'].value_counts()
# Out:
# Mkt&Fin    120
# Mkt&HR      95
# Name: Post Graduation Specialisation, dtype: int64

# %% [markdown]
# # Status of Placement

# %%
sns.set_theme(style='darkgrid')
ax = sns.countplot(y='Status of Placement', data=df_categorical)
df_categorical['Status of Placement'].value_counts()
# Out:
# Placed        148
# Not Placed     67
# Name: Status of Placement, dtype: int64

# %% [markdown]
# # Data Processing

# %%
df.isnull().sum()
# Out:
# gender                                                    0
# Secondary Education Percentage - 10th Grade               0
# Board of Secondary Education                              0
# Higher Secondary Education Percentage - 12th Grade        0
# Board of Higher Secondary Education                       0
# Specialization in  Higher Secondary Education             0
# Degree Percentage                                         0
# Field of Degree Education                                 0
# Work Experience                                           0
# Employability test percentage ( conducted by college)     0
# Post Graduation Specialisation                            0
# Post Graduation Percentage                                0
# Status of Placement                                       0
# salary                                                   67
# dtype: int64

# %%
df_numerical.var()
# Out:
# Secondary Education Percentage - 10th Grade              1.172284e+02
# Higher Secondary Education Percentage - 12th Grade       1.187557e+02
# Degree Percentage                                        5.415110e+01
# Employability test percentage ( conducted by college)    1.762510e+02
# Post Graduation Percentage                               3.402838e+01
# salary                                                   8.734295e+09
# dtype: float64

# %%
CorrMat = df_numerical.corr()
sns.heatmap(CorrMat, annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # Encoding Categorical Data

# %%
one_hot_encoding = pd.get_dummies(df_categorical.drop(columns=['Status of Placement']))
one_hot_encoding
# Out:
#      gender_F  ...  Post Graduation Specialisation_Mkt&HR
# No             ...
# 1           0  ...                                      1
# 2           0  ...                                      0
# 3           0  ...                                      0
# 4           0  ...                                      1
# 5           0  ...                                      0
# ..        ...  ...                                    ...
# 211         0  ...                                      0
# 212         0  ...                                      0
# 213         0  ...                                      0
# 214         1  ...                                      1
# 215         0  ...                                      1
#
# [215 rows x 16 columns]

# %%
CorrMat = one_hot_encoding.join(df['salary']).corr()
CorrMat
# Out:
#                                                     gender_F  ...    salary
# gender_F                                            1.000000  ... -0.158912
# gender_M                                           -1.000000  ...  0.158912
# Board of Secondary Education _Central               0.019429  ... -0.005539
# Board of Secondary Education _Others               -0.019429  ...  0.005539
# Board of Higher Secondary Education_Central         0.065945  ...  0.007549
# Board of Higher Secondary Education_Others         -0.065945  ... -0.007549
# Specialization in  Higher Secondary Education_Arts  0.093246  ... -0.088253
# Specialization in  Higher Secondary Education_C...  0.001087  ... -0.014219
# Specialization in  Higher Secondary Education_S... -0.042682  ...  0.049547
# Field of Degree Education_Comm&Mgmt                 0.036215  ... -0.160322
# Field of Degree Education_Others                    0.093246  ... -0.016573
# ...

# %%
df_categorical.columns
# Out:
# Index(['gender', 'Board of Secondary Education ',
#        'Board of Higher Secondary Education',
#        'Specialization in  Higher Secondary Education',
#        'Field of Degree Education', 'Work Experience',
#        'Post Graduation Specialisation', 'Status of Placement'],
#       dtype='object')

# %%
colums_drop = ['Board of Secondary Education ','Board of Higher Secondary Education',
               'Specialization in  Higher Secondary Education',
               'Status of Placement']

one_hot_encoding = pd.get_dummies(df_categorical.drop(columns=colums_drop))
one_hot_encoding
# Out:
#      gender_F  ...  Post Graduation Specialisation_Mkt&HR
# No             ...
# 1           0  ...                                      1
# 2           0  ...                                      0
# 3           0  ...                                      0
# 4           0  ...                                      1
# 5           0  ...                                      0
# ..        ...  ...                                    ...
# 211         0  ...                                      0
# 212         0  ...                                      0
# 213         0  ...                                      0
# 214         1  ...                                      1
# 215         0  ...                                      1
#
# [215 rows x 9 columns]

# %% [markdown]
# # Normalization

# %%
df_numerical.columns
# Out:
# Index(['Secondary Education Percentage - 10th Grade',
#        'Higher Secondary Education Percentage - 12th Grade',
#        'Degree Percentage',
#        'Employability test percentage ( conducted by college)',
#        'Post Graduation Percentage', 'salary'],
#       dtype='object')

# %%
df_normalization = df[['Employability test percentage ( conducted by college)', 'Post Graduation Percentage']]

x_min = np.min(df_normalization)
x_max = np.max(df_normalization)

def normalization(x):
  return (x-x_min)/(x_max-x_min)

df_normalization = normalization(df_normalization)
df_normalization
# Out:
#      Employability test percentage ( conducted by college)  Post Graduation Percentage
# No
# 1                                             0.104167                        0.284483
# 2                                             0.760417                        0.564843
# 3                                             0.520833                        0.247001
# 4                                             0.333333                        0.308096
# 5                                             0.975000                        0.160795
# ..                                                 ...                             ...
# 211                                           0.854167                        0.872564
# 212                                           0.500000                        0.090330
# 213                                           0.187500                        0.693778
# 214                                           0.416667                        0.338081
# ...

# %% [markdown]
# # Encoded Data

# %%
df_encoded = one_hot_encoding.join(df_normalization).join(df['salary']).dropna()
df_encoded.reset_index(inplace=True)
df_encoded.drop(columns=['No'], inplace=True)
df_encoded
# Out:
#      gender_F  gender_M  ...  Post Graduation Percentage    salary
# 0           0         1  ...                    0.284483  270000.0
# 1           0         1  ...                    0.564843  200000.0
# 2           0         1  ...                    0.247001  250000.0
# 3           0         1  ...                    0.160795  425000.0
# 4           0         1  ...                    0.409670  252000.0
# ..        ...       ...  ...                         ...       ...
# 143         0         1  ...                    0.197901  216000.0
# 144         0         1  ...                    0.872564  400000.0
# 145         0         1  ...                    0.090330  275000.0
# 146         0         1  ...                    0.693778  295000.0
# 147         1         0  ...                    0.338081  204000.0
#
# [148 rows x 12 columns]

# %% [markdown]
# # Separating Data

# %%
x_train = df_encoded.iloc[:125].drop(columns=['salary'])
x_test = df_encoded.iloc[125:].drop(columns=['salary'])
x_data = df_encoded.drop(columns=['salary'])

y_train = df_encoded.iloc[:125]['salary']
y_test = df_encoded.iloc[125:]['salary']
y_data = df_encoded['salary']

# %% [markdown]
# # Principla Component Analysist

# %%
from sklearn.decomposition import PCA
pca = PCA()

pca_df = df_encoded.drop(columns=['salary'])
pca_df = pca.fit_transform(x_train)
look_var = pca.explained_variance_ratio_
look_var
# Out:
# array([3.00577326e-01, 2.31752960e-01, 2.20843259e-01, 1.73488753e-01,
#        4.01973539e-02, 1.77320608e-02, 1.54082875e-02, 1.70788271e-32,
#        1.17783775e-32, 5.31754920e-33, 1.58619083e-33])

# %%
cum_sum_eigenvalues = np.cumsum(look_var)

# Create the visualization plot
plt.bar(range(0,len(look_var)), look_var, alpha=0.5, align='center', label='Individual explained variance')
plt.step(range(0,len(cum_sum_eigenvalues)), cum_sum_eigenvalues, where='mid',label='Cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# percentage of variance higher or equal to 90%.

# %%
# percentage of variance higher or equal to 90%.
pca = PCA(n_components=6)
x_new_ratio = pca.fit_transform(x_data)
pca.explained_variance_ratio_
# Out:
# array([0.30098382, 0.23215354, 0.21613747, 0.17102798, 0.03889053,
#        0.02379559])

# %%
fig, axes = plt.subplots(1,2)
axes[0].scatter(x_data.iloc[:,0], x_data.iloc[:,1], c=y_data)
axes[0].set_xlabel('x1')
axes[0].set_ylabel('x2')
axes[0].set_title('Before Principal Component Analysis')

axes[1].scatter(x_new_ratio[:,0], x_new_ratio[:,1], c=y_data)
axes[1].set_xlabel('PC1')
axes[1].set_ylabel('PC2')
axes[1].set_title('After Principal Component Analysis')
# Out:
# Text(0.5, 1.0, 'After Principal Component Analysis')

# %%
x_new_ratio
# Out:
# array([[ 6.40455158e-01,  8.99320706e-01, -9.86540423e-01,
#          5.31924500e-01, -3.04368957e-01, -4.91919655e-02],
#        [-1.25272500e+00,  5.54247975e-01, -2.09034553e-01,
#          5.12845092e-01,  1.40020382e-01, -4.65582424e-02],
#        [ 9.08001245e-02, -9.19980720e-01, -3.66378816e-01,
#          2.09737935e-01, -8.13541974e-02,  6.17306106e-02],
#        [ 4.67435463e-02, -9.57526147e-01, -3.75908880e-01,
#          2.49153176e-01,  3.03193840e-01,  1.13398904e-01],
#        [-1.20089997e+00,  5.78991449e-01, -2.26864304e-01,
#          4.62996502e-01, -2.87446612e-01, -3.29223149e-02],
#        [ 4.73315516e-02, -9.40684679e-01, -3.51349554e-01,
#          2.51557689e-01,  2.77122683e-01,  5.01026279e-02],
#        [-1.18872716e-01,  5.09226843e-01, -4.58316163e-01,
#         -1.19023749e+00, -7.37634621e-02, -6.15356531e-02],
#        [-9.07764701e-01, -3.38892248e-01, -2.11731279e-02,
#         -5.48163326e-01, -3.09042953e-01, -3.74839677e-02],
# ...

# %% [markdown]
# # Multi layer Perception

# %% [markdown]
# Building Model Architecture

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# # model (RMSE)

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=16, activation=tf.keras.activations.sigmoid, input_dim=11, name="hidden_layer"),
    tf.keras.layers.Dense(units=16, activation=tf.keras.activations.sigmoid, name="hidden_layer_2"),
    tf.keras.layers.Dense(units=16, activation=tf.keras.activations.sigmoid, name="hidden_layer_3"),
    tf.keras.layers.Dense(units=16, activation=tf.keras.activations.sigmoid, name="hidden_layer_4"),
    tf.keras.layers.Dense(units=1, activation=tf.keras.activations.sigmoid)])
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden_layer (Dense)        (None, 16)                192
#
#  hidden_layer_2 (Dense)      (None, 16)                272
#
#  hidden_layer_3 (Dense)      (None, 16)                272
#
#  hidden_layer_4 (Dense)      (None, 16)                272
#
#  dense_9 (Dense)             (None, 1)                 17
#
# ...
# Total params: 1,025
# Trainable params: 1,025
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # model for data from PCA reduction Dimension

# %%
tf.random.set_seed(42)
model_pca = tf.keras.Sequential([
    tf.keras.layers.Dense(units=16, activation=tf.keras.activations.sigmoid, input_dim=6, name="hidden_layer"),
    tf.keras.layers.Dense(units=16, activation=tf.keras.activations.sigmoid, name="hidden_layer_2"),
    tf.keras.layers.Dense(units=16, activation=tf.keras.activations.sigmoid, name="hidden_layer_3"),
    tf.keras.layers.Dense(units=16, activation=tf.keras.activations.sigmoid, name="hidden_layer_4"),
    tf.keras.layers.Dense(units=1, activation=tf.keras.activations.sigmoid)])
model_pca.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden_layer (Dense)        (None, 16)                112
#
#  hidden_layer_2 (Dense)      (None, 16)                272
#
#  hidden_layer_3 (Dense)      (None, 16)                272
#
#  hidden_layer_4 (Dense)      (None, 16)                272
#
#  dense_10 (Dense)            (None, 1)                 17
#
# ...
# Total params: 945
# Trainable params: 945
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, Callback, ModelCheckpoint
import tensorflow.keras.backend as K

# RMSE
def root_mean_squared_error(y_true, y_pred):
  return K.sqrt(K.mean(K.square(y_pred - y_true)))

# compiling model 
model.compile(loss=root_mean_squared_error,
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["mae"])

# Hyperparameter Training and Setting Training
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=1e-1, patience=5, mode='min', cooldown=10, min_delta=0)
early_stop = EarlyStopping(monitor='loss', min_delta=0, patience=100, mode='min', restore_best_weights=True)
checkpoint = ModelCheckpoint("ModelPath", monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint, early_stop, reduce_lr]
batch_size = 1

# %% [markdown]
# # the result of regression model (RMSE)

# %%
#the result of regression model (RMSE)
history = model.fit(x_data,
                    y_data,
                    epochs=1000,
                    callbacks=callbacks_list,
                    batch_size=batch_size)
# Out:
# Epoch 1/1000
# 128/148 [========================>.....] - ETA: 0s - loss: 290991.7500 - mae: 290991.7500
# Epoch 1: loss improved from inf to 288655.03125, saving model to ModelPath
# INFO:tensorflow:Assets written to: ModelPath/assets
# 148/148 [==============================] - 2s 7ms/step - loss: 288655.0312 - mae: 288655.0312 - lr: 0.0010
# Epoch 2/1000
# 137/148 [==========================>...] - ETA: 0s - loss: 290218.5625 - mae: 290218.5625
# Epoch 2: loss did not improve from 288655.03125
# 148/148 [==============================] - 0s 2ms/step - loss: 288655.0312 - mae: 288655.0312 - lr: 0.0010
# Epoch 3/1000
# 128/148 [========================>.....] - ETA: 0s - loss: 285999.5000 - mae: 285999.5312
# Epoch 3: loss improved from 288655.03125 to 288654.96875, saving model to ModelPath
# INFO:tensorflow:Assets written to: ModelPath/assets
# 148/148 [==============================] - 1s 9ms/step - loss: 288654.9688 - mae: 288655.0000 - lr: 0.0010
# Epoch 4/1000
# ...

# %% [markdown]
# #  full data and using the data from the PCA result

# %%
# compiling model 
model_pca.compile(loss=root_mean_squared_error,
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["mae"])

history_PCA = model_pca.fit(x_new_ratio,
                    y_data,
                    epochs=1000,
                    callbacks=callbacks_list,
                    batch_size=batch_size)
# Out:
# Epoch 1/1000
# 136/148 [==========================>...] - ETA: 0s - loss: 289014.2812 - mae: 289014.2812
# Epoch 1: loss did not improve from 288654.90625
# 148/148 [==============================] - 1s 2ms/step - loss: 288655.0312 - mae: 288655.0312 - lr: 0.0010
# Epoch 2/1000
# 138/148 [==========================>...] - ETA: 0s - loss: 289789.4375 - mae: 289789.4375
# Epoch 2: loss did not improve from 288654.90625
# 148/148 [==============================] - 0s 2ms/step - loss: 288655.0312 - mae: 288655.0312 - lr: 0.0010
# Epoch 3/1000
# 132/148 [=========================>....] - ETA: 0s - loss: 287029.8125 - mae: 287029.8438
# Epoch 3: loss did not improve from 288654.90625
# 148/148 [==============================] - 0s 2ms/step - loss: 288654.9688 - mae: 288655.0000 - lr: 0.0010
# Epoch 4/1000
# 138/148 [==========================>...] - ETA: 0s - loss: 286753.1875 - mae: 286753.1875
# Epoch 4: loss did not improve from 288654.90625
# ...
